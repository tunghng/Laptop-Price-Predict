# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv('laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
print(df.corr())
# Out:
#             Unnamed: 0    Inches     Price
# Unnamed: 0    1.000000 -0.087936  0.067984
# Inches       -0.087936  1.000000  0.068197
# Price         0.067984  0.068197  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df['Weight'] = df['Weight'].str.replace('kg', '')
df['Weight'] = df['Weight'].astype(float)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
# [1303 rows x 12 columns]

# %%
df.OpSys.value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
df.OpSys = df.OpSys.astype(str)

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
# [1303 rows x 11 columns]

# %%
df.Gpu = df.Gpu.apply(lambda x: x.split()[0])
df.Gpu.value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu, dtype: int64

# %%
df.Ram.value_counts()
# Out:
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: Ram, dtype: int64

# %%
df.Ram = df.Ram.str.replace('GB', '')

# %%
df.Ram.astype(int)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu Ram               Memory    Gpu  \
# 0                     Intel Core i5 2.3GHz   8            128GB SSD  Intel
# 1                     Intel Core i5 1.8GHz   8  128GB Flash Storage  Intel
# 2               Intel Core i5 7200U 2.5GHz   8            256GB SSD  Intel
# 3                     Intel Core i7 2.7GHz  16            512GB SSD    AMD
# 4                     Intel Core i5 3.1GHz   8            256GB SSD  Intel
# ...                                    ...  ..                  ...    ...
# 1298            Intel Core i7 6500U 2.5GHz   4            128GB SSD  Intel
# 1299            Intel Core i7 6500U 2.5GHz  16            512GB SSD  Intel
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2   64GB Flash Storage  Intel
# 1301            Intel Core i7 6500U 2.5GHz   6              1TB HDD    AMD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4            500GB HDD  Intel
#
#            OpSys  Weight        Price
# 0          macOS    1.37   71378.6832
# 1          macOS    1.34   47895.5232
# 2          No OS    1.86   30636.0000
# 3          macOS    1.83  135195.3360
# 4          macOS    1.37   96095.8080
# ...          ...     ...          ...
# 1298  Windows 10    1.80   33992.6400
# 1299  Windows 10    1.30   79866.7200
# 1300  Windows 10    1.50   12201.1200
# 1301  Windows 10    2.19   40705.9200
# 1302  Windows 10    2.20   19660.3200
#
# [1303 rows x 11 columns]

# %%
df.Cpu.value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['CpuName'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.CpuName
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: CpuName, Length: 1303, dtype: object

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu Ram               Memory    Gpu  \
# 0                     Intel Core i5 2.3GHz   8            128GB SSD  Intel
# 1                     Intel Core i5 1.8GHz   8  128GB Flash Storage  Intel
# 2               Intel Core i5 7200U 2.5GHz   8            256GB SSD  Intel
# 3                     Intel Core i7 2.7GHz  16            512GB SSD    AMD
# 4                     Intel Core i5 3.1GHz   8            256GB SSD  Intel
# ...                                    ...  ..                  ...    ...
# 1298            Intel Core i7 6500U 2.5GHz   4            128GB SSD  Intel
# 1299            Intel Core i7 6500U 2.5GHz  16            512GB SSD  Intel
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2   64GB Flash Storage  Intel
# 1301            Intel Core i7 6500U 2.5GHz   6              1TB HDD    AMD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4            500GB HDD  Intel
#
#            OpSys  Weight        Price             CpuName
# 0          macOS    1.37   71378.6832       Intel Core i5
# 1          macOS    1.34   47895.5232       Intel Core i5
# 2          No OS    1.86   30636.0000       Intel Core i5
# 3          macOS    1.83  135195.3360       Intel Core i7
# 4          macOS    1.37   96095.8080       Intel Core i5
# ...          ...     ...          ...                 ...
# 1298  Windows 10    1.80   33992.6400       Intel Core i7
# 1299  Windows 10    1.30   79866.7200       Intel Core i7
# 1300  Windows 10    1.50   12201.1200  Intel Celeron Dual
# 1301  Windows 10    2.19   40705.9200       Intel Core i7
# 1302  Windows 10    2.20   19660.3200  Intel Celeron Dual
#
# [1303 rows x 12 columns]

# %%
df['Ghz'] = df.Cpu.apply(lambda x: x.split()[-1])

df.Ghz = df.Ghz.str.replace('GHz', '')

# %%
df.Ghz.value_counts()
# Out:
# 2.5     290
# 2.7     165
# 2.8     165
# 1.6     133
# 2.3      86
# 1.8      78
# 2.6      76
# 2        67
# 1.1      53
# 2.4      52
# 2.9      21
# 3        19
# 2.0      19
# 1.2      15
# 1.44     12
# 2.2      11
# 1.5      10
# 1.3       6
# 3.6       5
# 0.9       4
# 3.1       3
# 2.1       3
# 2.50      3
# 1.9       2
# 1.60      1
# 3.2       1
# 1.0       1
# 1.92      1
# 2.70      1
# Name: Ghz, dtype: int64

# %%
df.Ghz = df.Ghz.astype(float)

# %%
df.drop('Cpu', axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600   8            128GB SSD
# 1                                       1440x900   8  128GB Flash Storage
# 2                              Full HD 1920x1080   8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800  16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600   8            256GB SSD
# ...                                          ...  ..                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080   4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  16            512GB SSD
# 1300                                    1366x768   2   64GB Flash Storage
# 1301                                    1366x768   6              1TB HDD
# 1302                                    1366x768   4            500GB HDD
#
#         Gpu       OpSys  Weight        Price             CpuName  Ghz
# 0     Intel       macOS    1.37   71378.6832       Intel Core i5  2.3
# 1     Intel       macOS    1.34   47895.5232       Intel Core i5  1.8
# 2     Intel       No OS    1.86   30636.0000       Intel Core i5  2.5
# 3       AMD       macOS    1.83  135195.3360       Intel Core i7  2.7
# 4     Intel       macOS    1.37   96095.8080       Intel Core i5  3.1
# ...     ...         ...     ...          ...                 ...  ...
# 1298  Intel  Windows 10    1.80   33992.6400       Intel Core i7  2.5
# 1299  Intel  Windows 10    1.30   79866.7200       Intel Core i7  2.5
# 1300  Intel  Windows 10    1.50   12201.1200  Intel Celeron Dual  1.6
# 1301    AMD  Windows 10    2.19   40705.9200       Intel Core i7  2.5
# 1302  Intel  Windows 10    2.20   19660.3200  Intel Celeron Dual  1.6
#
# [1303 rows x 12 columns]

# %%
def fetch_cpu(text):
    if text in ['Intel Core i5', 'Intel Core i7', 'Intel Core i3']:
        return text
    else:
        if text.split()[0] == 'Intel':
            return "other type of Intel"
        else:
            return 'AMD'

df.CpuName = df.CpuName.apply(fetch_cpu)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600   8            128GB SSD
# 1                                       1440x900   8  128GB Flash Storage
# 2                              Full HD 1920x1080   8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800  16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600   8            256GB SSD
# ...                                          ...  ..                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080   4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  16            512GB SSD
# 1300                                    1366x768   2   64GB Flash Storage
# 1301                                    1366x768   6              1TB HDD
# 1302                                    1366x768   4            500GB HDD
#
#         Gpu       OpSys  Weight        Price              CpuName  Ghz
# 0     Intel       macOS    1.37   71378.6832        Intel Core i5  2.3
# 1     Intel       macOS    1.34   47895.5232        Intel Core i5  1.8
# 2     Intel       No OS    1.86   30636.0000        Intel Core i5  2.5
# 3       AMD       macOS    1.83  135195.3360        Intel Core i7  2.7
# 4     Intel       macOS    1.37   96095.8080        Intel Core i5  3.1
# ...     ...         ...     ...          ...                  ...  ...
# 1298  Intel  Windows 10    1.80   33992.6400        Intel Core i7  2.5
# 1299  Intel  Windows 10    1.30   79866.7200        Intel Core i7  2.5
# 1300  Intel  Windows 10    1.50   12201.1200  other type of Intel  1.6
# 1301    AMD  Windows 10    2.19   40705.9200        Intel Core i7  2.5
# 1302  Intel  Windows 10    2.20   19660.3200  other type of Intel  1.6
#
# [1303 rows x 12 columns]

# %%
df['X_res'] = df.ScreenResolution.apply(lambda x: (x.split()[-1]).split('x')[0])
df['Y_res'] = df.ScreenResolution.apply(lambda x: (x.split()[-1]).split('x')[1])

# %%
df.X_res = df.X_res.astype(float)
df.Y_res = df.Y_res.astype(float)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600   8            128GB SSD
# 1                                       1440x900   8  128GB Flash Storage
# 2                              Full HD 1920x1080   8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800  16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600   8            256GB SSD
# ...                                          ...  ..                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080   4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  16            512GB SSD
# 1300                                    1366x768   2   64GB Flash Storage
# 1301                                    1366x768   6              1TB HDD
# 1302                                    1366x768   4            500GB HDD
#
#         Gpu       OpSys  Weight        Price              CpuName  Ghz  \
# 0     Intel       macOS    1.37   71378.6832        Intel Core i5  2.3
# 1     Intel       macOS    1.34   47895.5232        Intel Core i5  1.8
# 2     Intel       No OS    1.86   30636.0000        Intel Core i5  2.5
# 3       AMD       macOS    1.83  135195.3360        Intel Core i7  2.7
# 4     Intel       macOS    1.37   96095.8080        Intel Core i5  3.1
# ...     ...         ...     ...          ...                  ...  ...
# 1298  Intel  Windows 10    1.80   33992.6400        Intel Core i7  2.5
# 1299  Intel  Windows 10    1.30   79866.7200        Intel Core i7  2.5
# 1300  Intel  Windows 10    1.50   12201.1200  other type of Intel  1.6
# 1301    AMD  Windows 10    2.19   40705.9200        Intel Core i7  2.5
# 1302  Intel  Windows 10    2.20   19660.3200  other type of Intel  1.6
#
#        X_res   Y_res
# 0     2560.0  1600.0
# 1     1440.0   900.0
# 2     1920.0  1080.0
# 3     2880.0  1800.0
# 4     2560.0  1600.0
# ...      ...     ...
# 1298  1920.0  1080.0
# 1299  3200.0  1800.0
# 1300  1366.0   768.0
# 1301  1366.0   768.0
# 1302  1366.0   768.0
#
# [1303 rows x 14 columns]

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')
df.drop(['X_res', 'Y_res'], axis = 1, inplace = True)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600   8            128GB SSD
# 1                                       1440x900   8  128GB Flash Storage
# 2                              Full HD 1920x1080   8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800  16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600   8            256GB SSD
# ...                                          ...  ..                  ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080   4            128GB SSD
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  16            512GB SSD
# 1300                                    1366x768   2   64GB Flash Storage
# 1301                                    1366x768   6              1TB HDD
# 1302                                    1366x768   4            500GB HDD
#
#         Gpu       OpSys  Weight        Price              CpuName  Ghz  \
# 0     Intel       macOS    1.37   71378.6832        Intel Core i5  2.3
# 1     Intel       macOS    1.34   47895.5232        Intel Core i5  1.8
# 2     Intel       No OS    1.86   30636.0000        Intel Core i5  2.5
# 3       AMD       macOS    1.83  135195.3360        Intel Core i7  2.7
# 4     Intel       macOS    1.37   96095.8080        Intel Core i5  3.1
# ...     ...         ...     ...          ...                  ...  ...
# 1298  Intel  Windows 10    1.80   33992.6400        Intel Core i7  2.5
# 1299  Intel  Windows 10    1.30   79866.7200        Intel Core i7  2.5
# 1300  Intel  Windows 10    1.50   12201.1200  other type of Intel  1.6
# 1301    AMD  Windows 10    2.19   40705.9200        Intel Core i7  2.5
# 1302  Intel  Windows 10    2.20   19660.3200  other type of Intel  1.6
#
#              ppi
# 0     226.983005
# 1     127.677940
# 2     141.211998
# 3     220.534624
# 4     226.983005
# ...          ...
# 1298  157.350512
# 1299  276.053530
# 1300  111.935204
# 1301  100.454670
# 1302  100.454670
#
# [1303 rows x 13 columns]

# %%
df.drop('Inches', axis = 1, inplace = True)

# %%
df['IPS'] = df.ScreenResolution.apply(lambda x: 1 if 'IPS' in x else 0)
df['Touchscreen'] = df.ScreenResolution.apply(lambda x: 1 if 'Touchscreen' in x else 0)
df
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
#      Ram               Memory    Gpu       OpSys  Weight        Price  \
# 0      8            128GB SSD  Intel       macOS    1.37   71378.6832
# 1      8  128GB Flash Storage  Intel       macOS    1.34   47895.5232
# 2      8            256GB SSD  Intel       No OS    1.86   30636.0000
# 3     16            512GB SSD    AMD       macOS    1.83  135195.3360
# 4      8            256GB SSD  Intel       macOS    1.37   96095.8080
# ...   ..                  ...    ...         ...     ...          ...
# 1298   4            128GB SSD  Intel  Windows 10    1.80   33992.6400
# 1299  16            512GB SSD  Intel  Windows 10    1.30   79866.7200
# 1300   2   64GB Flash Storage  Intel  Windows 10    1.50   12201.1200
# 1301   6              1TB HDD    AMD  Windows 10    2.19   40705.9200
# 1302   4            500GB HDD  Intel  Windows 10    2.20   19660.3200
#
#                   CpuName  Ghz         ppi  IPS  Touchscreen
# 0           Intel Core i5  2.3  226.983005    1            0
# 1           Intel Core i5  1.8  127.677940    0            0
# 2           Intel Core i5  2.5  141.211998    0            0
# 3           Intel Core i7  2.7  220.534624    1            0
# 4           Intel Core i5  3.1  226.983005    1            0
# ...                   ...  ...         ...  ...          ...
# 1298        Intel Core i7  2.5  157.350512    1            1
# 1299        Intel Core i7  2.5  276.053530    1            1
# 1300  other type of Intel  1.6  111.935204    0            0
# 1301        Intel Core i7  2.5  100.454670    0            0
# 1302  other type of Intel  1.6  100.454670    0            0
#
# [1303 rows x 14 columns]

# %%
df.drop('ScreenResolution', axis = 1, inplace = True)

# %%
df.Memory.value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\vcbna\AppData\Local\Temp\ipykernel_11244\4023190604.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\vcbna\AppData\Local\Temp\ipykernel_11244\4023190604.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.drop('Memory', axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName Ram    Gpu       OpSys  Weight        Price  \
# 0      Apple           Ultrabook   8  Intel       macOS    1.37   71378.6832
# 1      Apple           Ultrabook   8  Intel       macOS    1.34   47895.5232
# 2         HP            Notebook   8  Intel       No OS    1.86   30636.0000
# 3      Apple           Ultrabook  16    AMD       macOS    1.83  135195.3360
# 4      Apple           Ultrabook   8  Intel       macOS    1.37   96095.8080
# ...      ...                 ...  ..    ...         ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible   4  Intel  Windows 10    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible  16  Intel  Windows 10    1.30   79866.7200
# 1300  Lenovo            Notebook   2  Intel  Windows 10    1.50   12201.1200
# 1301      HP            Notebook   6    AMD  Windows 10    2.19   40705.9200
# 1302    Asus            Notebook   4  Intel  Windows 10    2.20   19660.3200
#
#                   CpuName  Ghz         ppi  IPS  Touchscreen  SSD   HDD  \
# 0           Intel Core i5  2.3  226.983005    1            0  128     0
# 1           Intel Core i5  1.8  127.677940    0            0    0     0
# 2           Intel Core i5  2.5  141.211998    0            0  256     0
# 3           Intel Core i7  2.7  220.534624    1            0  512     0
# 4           Intel Core i5  3.1  226.983005    1            0  256     0
# ...                   ...  ...         ...  ...          ...  ...   ...
# 1298        Intel Core i7  2.5  157.350512    1            1  128     0
# 1299        Intel Core i7  2.5  276.053530    1            1  512     0
# 1300  other type of Intel  1.6  111.935204    0            0    0     0
# 1301        Intel Core i7  2.5  100.454670    0            0    0  1000
# 1302  other type of Intel  1.6  100.454670    0            0    0   500
#
#       Hybrid  Flash_Storage
# 0          0              0
# 1          0            128
# 2          0              0
# 3          0              0
# 4          0              0
# ...      ...            ...
# 1298       0              0
# 1299       0              0
# 1300       0             64
# 1301       0              0
# 1302       0              0
#
# [1303 rows x 16 columns]

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'
    
df['os'] = df['OpSys'].apply(cat_os)

# %%
df
# Out:
#      Company            TypeName Ram    Gpu       OpSys  Weight        Price  \
# 0      Apple           Ultrabook   8  Intel       macOS    1.37   71378.6832
# 1      Apple           Ultrabook   8  Intel       macOS    1.34   47895.5232
# 2         HP            Notebook   8  Intel       No OS    1.86   30636.0000
# 3      Apple           Ultrabook  16    AMD       macOS    1.83  135195.3360
# 4      Apple           Ultrabook   8  Intel       macOS    1.37   96095.8080
# ...      ...                 ...  ..    ...         ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible   4  Intel  Windows 10    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible  16  Intel  Windows 10    1.30   79866.7200
# 1300  Lenovo            Notebook   2  Intel  Windows 10    1.50   12201.1200
# 1301      HP            Notebook   6    AMD  Windows 10    2.19   40705.9200
# 1302    Asus            Notebook   4  Intel  Windows 10    2.20   19660.3200
#
#                   CpuName  Ghz         ppi  IPS  Touchscreen  SSD   HDD  \
# 0           Intel Core i5  2.3  226.983005    1            0  128     0
# 1           Intel Core i5  1.8  127.677940    0            0    0     0
# 2           Intel Core i5  2.5  141.211998    0            0  256     0
# 3           Intel Core i7  2.7  220.534624    1            0  512     0
# 4           Intel Core i5  3.1  226.983005    1            0  256     0
# ...                   ...  ...         ...  ...          ...  ...   ...
# 1298        Intel Core i7  2.5  157.350512    1            1  128     0
# 1299        Intel Core i7  2.5  276.053530    1            1  512     0
# 1300  other type of Intel  1.6  111.935204    0            0    0     0
# 1301        Intel Core i7  2.5  100.454670    0            0    0  1000
# 1302  other type of Intel  1.6  100.454670    0            0    0   500
#
#       Hybrid  Flash_Storage                  os
# 0          0              0                 Mac
# 1          0            128                 Mac
# 2          0              0  Others/No OS/Linux
# 3          0              0                 Mac
# 4          0              0                 Mac
# ...      ...            ...                 ...
# 1298       0              0             Windows
# 1299       0              0             Windows
# 1300       0             64             Windows
# 1301       0              0             Windows
# 1302       0              0             Windows
#
# [1303 rows x 17 columns]

# %%
df.corr()['Price']
# Out:
# Weight           0.210370
# Price            1.000000
# Ghz              0.430293
# ppi              0.473487
# IPS              0.252208
# Touchscreen      0.191226
# SSD              0.670799
# HDD             -0.096441
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(['Hybrid', 'Flash_Storage', 'HDD'], axis = 1, inplace = True)
df
# Out:
#      Company            TypeName Ram    Gpu       OpSys  Weight        Price  \
# 0      Apple           Ultrabook   8  Intel       macOS    1.37   71378.6832
# 1      Apple           Ultrabook   8  Intel       macOS    1.34   47895.5232
# 2         HP            Notebook   8  Intel       No OS    1.86   30636.0000
# 3      Apple           Ultrabook  16    AMD       macOS    1.83  135195.3360
# 4      Apple           Ultrabook   8  Intel       macOS    1.37   96095.8080
# ...      ...                 ...  ..    ...         ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible   4  Intel  Windows 10    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible  16  Intel  Windows 10    1.30   79866.7200
# 1300  Lenovo            Notebook   2  Intel  Windows 10    1.50   12201.1200
# 1301      HP            Notebook   6    AMD  Windows 10    2.19   40705.9200
# 1302    Asus            Notebook   4  Intel  Windows 10    2.20   19660.3200
#
#                   CpuName  Ghz         ppi  IPS  Touchscreen  SSD  \
# 0           Intel Core i5  2.3  226.983005    1            0  128
# 1           Intel Core i5  1.8  127.677940    0            0    0
# 2           Intel Core i5  2.5  141.211998    0            0  256
# 3           Intel Core i7  2.7  220.534624    1            0  512
# 4           Intel Core i5  3.1  226.983005    1            0  256
# ...                   ...  ...         ...  ...          ...  ...
# 1298        Intel Core i7  2.5  157.350512    1            1  128
# 1299        Intel Core i7  2.5  276.053530    1            1  512
# 1300  other type of Intel  1.6  111.935204    0            0    0
# 1301        Intel Core i7  2.5  100.454670    0            0    0
# 1302  other type of Intel  1.6  100.454670    0            0    0
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1303 rows x 14 columns]

# %%
import seaborn as sns 

sns.distplot(df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
X = df.drop('Price', axis = 1)
y = np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)
